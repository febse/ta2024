# %%
# from __future__ import print_function, division
# from builtins import range
# # Note: you may need to update your version of future
# # sudo pip install -U future


# import numpy as np
# import matplotlib.pyplot as plt

# def label_to_indicator(y, K):
#     N = len(y)
#     ind = np.zeros((N, K))
#     for i in range(N):
#         ind[i, y[i]] = 1
#     return ind


# X_train, X_test, Y_train, Y_test = train_test_split(data, labels, test_size=0.2)

# D = 4
# K = 3

# # Create the indicator matrices

# Y_train_indicators = label_to_indicator(Y_train, K)
# Y_test_indicators = label_to_indicator(Y_test, K)

# # randomly initialize weights
# W = np.random.randn(D, K)
# b = np.zeros(K)

# # make predictions
# def softmax(x):
#     return np.exp(x) / np.exp(x).sum(axis=1, keepdims=True)

# def forward(X, W, b):
#     return softmax(X.dot(W) + b)

# def predict(P_Y_given_X):
#     return np.argmax(P_Y_given_X, axis=1)

# # calculate the accuracy
# def classification_rate(Y, P):
#     return np.mean(Y == P)

# def loss_fn(Y, pY):
#     return -np.sum(Y * np.log(pY)) / len(Y)


# # train loop
# losses_train = []
# losses_test = []

# # Hyperparameters
# # - learning rate
# lr = 0.001
# # - number of epochs
# epochsn = 10000

# for i in range(epochsn):
#     # Calculate the probabilities of the classes
#     y_hat_train = forward(X_train, W, b)
#     y_hat_test = forward(X_test, W, b)

#     # Calculate the losses
#     loss_train = loss_fn(Y_train_indicators, y_hat_train)
#     loss_test = loss_fn(Y_test_indicators, y_hat_test)
    
#     losses_train.append(loss_train)
#     losses_test.append(loss_test)

#     # Update the weights
    
#     W -= lr*X_train.T.dot(y_hat_train - Y_train_indicators)
#     b -= lr*(y_hat_train - Y_train_indicators).sum(axis=0)
    
#     if i % 1000 == 0:
#         print(i, loss_train, loss_test)

# print("Train set classification_rate:", classification_rate(Y_train, predict(y_hat_train)))
# print("Tet set test classification_rate:", classification_rate(Y_test, predict(y_hat_test)))

# plt.plot(losses_train, label="Train loss")
# plt.plot(losses_test, label="Test loss")
# plt.legend()
# plt.show()
